# %%
import pandas as pd
import numpy as np
import scipy.stats as scs
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_excel("health.xlsx")

# Remove unwanted columns
del df['Åldersgrupp']
del df['Sömngrupp']

# Assign gender string
df['Kön'] = df['Kön'].replace({1,2},{'Kvinna','Man'})

# Assign civilstånd
mapping = {1: 'Gift/Sambo',
           2: 'Änka/Änkling ej omgift',
           3: 'Skild, ej omgift',
           4: 'Särbo',
           5: 'Ogift',
           6: 'Annat'}
df['Civilstånd'] = df['Civilstånd'].map(mapping)

# Assign utbildningsnivå
mapping = {1: 'Folkskolenivå eller lägre',
           2: 'Grundskola/Realexamen',
           3: 'Studentexamen',
           4: 'Fölkhögskola/Yrkesutbildning',
           5: 'Ofullständig akademisk utbildning',
           6: 'Universitet/Högskola med examen'}
df['Utbildningsnivå'] = df['Utbildningsnivå'].map(mapping)

# Assign sysselsättning
mapping = {1: 'Arbete', 
           2: 'Studier', 
           3: 'Arbetslös', 
           4: 'Sjukskriven/sjukersättning', 
           5: 'Ålderspensionär', 
           6: 'Icke-förvärvsarbetande av annan orsak'}
df['Sysselsättning'] = df['Sysselsättning'].map(mapping)

# Assign boende
mapping = {1: 'Hyresrätt', 
           2: 'Bostadrätt', 
           3: 'Radhus, villa eller liknande', 
           4: 'Särskilt boende', 
           5: 'Annat'}
df['Boende'] = df['Boende'].map(mapping)

# Assign living situation
mapping = {1: 'Ensamboende', 
           2: 'Make/maka/sambo', 
           3: 'Barn', 
           4: 'Förälder', 
           5: 'Annan',
           6: 'Familj (Partner och barn/ föräldrar och syskon)'}
df['Tillsammans_med'] = df['Tillsammans_med'].map(mapping)

# Data on self-reported satisfaction levels were originally ordered reverse, e.g. 5 being 'low' and 1 'high'.
mapping = {1: 5, 2: 4, 3: 3, 4: 2, 5: 1} # Reversing this.
df['Vardagstillfredsställelse'] = df['Vardagstillfredsställelse'].map(mapping)

# Same with health
df['Hälsa'] = df['Hälsa'].map(mapping)


df
# Out:
#     Deltagare  Ålder     Kön        Civilstånd  \
# 0           1     33  Kvinna        Gift/Sambo
# 1           2     32  Kvinna        Gift/Sambo
# 2           3     30  Kvinna        Gift/Sambo
# 3           4     32  Kvinna        Gift/Sambo
# 4           5     34     Man        Gift/Sambo
# 5           6     30  Kvinna             Annat
# 6           7     34     Man        Gift/Sambo
# 7           8     45     Man        Gift/Sambo
# 8           9     38  Kvinna             Ogift
# 9          10     31     Man             Särbo
# 10         11     43     Man        Gift/Sambo
# 11         12     37     Man        Gift/Sambo
# 12         13     40     Man        Gift/Sambo
# 13         14     30  Kvinna             Ogift
# 14         15     36     Man  Skild, ej omgift
# 15         16     31     Man        Gift/Sambo
# 16         17     36     Man             Ogift
# 17         18     29     Man  Skild, ej omgift
# 18         19     39     Man             Ogift
# 19         20     29     Man        Gift/Sambo
# 20         21     30  Kvinna        Gift/Sambo
# 21         22     39     Man        Gift/Sambo
# 22         23     40  Kvinna        Gift/Sambo
# 23         24     40  Kvinna        Gift/Sambo
# 24         25     42     Man        Gift/Sambo
# 25         26     45  Kvinna             Annat
# 26         27     39     Man             Annat
# 27         28     36     Man        Gift/Sambo
# 28         29     37  Kvinna             Annat
# 29         30     33  Kvinna        Gift/Sambo
# 30         31     30  Kvinna             Ogift
# 31         32     37  Kvinna             Ogift
# 32         33     34  Kvinna             Ogift
# 33         34     29  Kvinna             Ogift
# 34         35     41  Kvinna             Ogift
# 35         36     41  Kvinna        Gift/Sambo
# 36         37     31  Kvinna             Ogift
# 37         38     32     Man             Ogift
# 38         39     30  Kvinna             Ogift
# 39         40     46  Kvinna             Ogift
# 40         41     44  Kvinna             Ogift
# 41         42     32  Kvinna             Ogift
#
#                       Utbildningsnivå                         Sysselsättning  \
# 0     Universitet/Högskola med examen                                 Arbete
# 1                       Studentexamen                                 Arbete
# 2     Universitet/Högskola med examen                                 Arbete
# 3     Universitet/Högskola med examen                                 Arbete
# 4     Universitet/Högskola med examen                                 Arbete
# 5     Universitet/Högskola med examen                                 Arbete
# 6   Ofullständig akademisk utbildning  Icke-förvärvsarbetande av annan orsak
# 7        Fölkhögskola/Yrkesutbildning                                 Arbete
# 8   Ofullständig akademisk utbildning                                 Arbete
# 9                       Studentexamen                                 Arbete
# 10  Ofullständig akademisk utbildning                                Studier
# 11  Ofullständig akademisk utbildning                                Studier
# 12  Ofullständig akademisk utbildning                                Studier
# 13  Ofullständig akademisk utbildning                                 Arbete
# 14  Ofullständig akademisk utbildning                                 Arbete
# 15  Ofullständig akademisk utbildning                                Studier
# 16  Ofullständig akademisk utbildning                                 Arbete
# 17  Ofullständig akademisk utbildning                                 Arbete
# 18  Ofullständig akademisk utbildning                                Studier
# 19       Fölkhögskola/Yrkesutbildning                                 Arbete
# 20                      Studentexamen                                 Arbete
# 21                      Studentexamen                                Studier
# 22                      Studentexamen                                 Arbete
# 23                      Studentexamen                                 Arbete
# 24       Fölkhögskola/Yrkesutbildning                                 Arbete
# 25       Fölkhögskola/Yrkesutbildning             Sjukskriven/sjukersättning
# 26                      Studentexamen                                 Arbete
# 27    Universitet/Högskola med examen                                 Arbete
# 28                      Studentexamen                                Studier
# 29    Universitet/Högskola med examen                                 Arbete
# 30                      Studentexamen                                 Arbete
# 31    Universitet/Högskola med examen                                Studier
# 32       Fölkhögskola/Yrkesutbildning                                 Arbete
# 33                      Studentexamen                                Studier
# 34       Fölkhögskola/Yrkesutbildning                                 Arbete
# 35    Universitet/Högskola med examen                                 Arbete
# 36    Universitet/Högskola med examen                                 Arbete
# 37                      Studentexamen                                 Arbete
# 38  Ofullständig akademisk utbildning                                Studier
# 39       Fölkhögskola/Yrkesutbildning                                 Arbete
# 40              Grundskola/Realexamen                                 Arbete
# 41       Fölkhögskola/Yrkesutbildning                                 Arbete
#
#                           Boende  \
# 0                     Bostadrätt
# 1                      Hyresrätt
# 2                     Bostadrätt
# 3                      Hyresrätt
# 4                      Hyresrätt
# 5                      Hyresrätt
# 6   Radhus, villa eller liknande
# 7   Radhus, villa eller liknande
# 8                      Hyresrätt
# 9   Radhus, villa eller liknande
# 10                     Hyresrätt
# 11                     Hyresrätt
# 12                     Hyresrätt
# 13                     Hyresrätt
# 14                     Hyresrätt
# 15                     Hyresrätt
# 16                     Hyresrätt
# 17                     Hyresrätt
# 18                     Hyresrätt
# 19                     Hyresrätt
# 20                     Hyresrätt
# 21  Radhus, villa eller liknande
# 22                     Hyresrätt
# 23  Radhus, villa eller liknande
# 24  Radhus, villa eller liknande
# 25  Radhus, villa eller liknande
# 26  Radhus, villa eller liknande
# 27                     Hyresrätt
# 28                     Hyresrätt
# 29  Radhus, villa eller liknande
# 30                     Hyresrätt
# 31                     Hyresrätt
# 32                     Hyresrätt
# 33                    Bostadrätt
# 34  Radhus, villa eller liknande
# 35                     Hyresrätt
# 36                     Hyresrätt
# 37                     Hyresrätt
# 38                     Hyresrätt
# 39                     Hyresrätt
# 40                         Annat
# 41                     Hyresrätt
#
#                                     Tillsammans_med  \
# 0                                   Make/maka/sambo
# 1   Familj (Partner och barn/ föräldrar och syskon)
# 2                                   Make/maka/sambo
# 3   Familj (Partner och barn/ föräldrar och syskon)
# 4                                   Make/maka/sambo
# 5                                       Ensamboende
# 6   Familj (Partner och barn/ föräldrar och syskon)
# 7   Familj (Partner och barn/ föräldrar och syskon)
# 8                                       Ensamboende
# 9                                       Ensamboende
# 10                                  Make/maka/sambo
# 11                                  Make/maka/sambo
# 12                                  Make/maka/sambo
# 13                                      Ensamboende
# 14  Familj (Partner och barn/ föräldrar och syskon)
# 15  Familj (Partner och barn/ föräldrar och syskon)
# 16                                         Förälder
# 17  Familj (Partner och barn/ föräldrar och syskon)
# 18  Familj (Partner och barn/ föräldrar och syskon)
# 19                                  Make/maka/sambo
# 20  Familj (Partner och barn/ föräldrar och syskon)
# 21  Familj (Partner och barn/ föräldrar och syskon)
# 22                                  Make/maka/sambo
# 23  Familj (Partner och barn/ föräldrar och syskon)
# 24  Familj (Partner och barn/ föräldrar och syskon)
# 25                                      Ensamboende
# 26  Familj (Partner och barn/ föräldrar och syskon)
# 27                                  Make/maka/sambo
# 28                                      Ensamboende
# 29  Familj (Partner och barn/ föräldrar och syskon)
# 30                                            Annan
# 31                                      Ensamboende
# 32                                      Ensamboende
# 33                                      Ensamboende
# 34                                  Make/maka/sambo
# 35                                  Make/maka/sambo
# 36                                      Ensamboende
# 37                                            Annan
# 38                                  Make/maka/sambo
# 39                                            Annan
# 40                                      Ensamboende
# 41                                      Ensamboende
#
#     Vardagstillfredsställelse  Hälsa  Arbete  Skötsel  Lek  Rekreation  Sömn  \
# 0                           4      4     420      270  120         150   480
# 1                           5      5     420      195   60         240   525
# 2                           4      4     450      210    0         300   480
# 3                           4      3     420      300    0         240   480
# 4                           4      4     405      315    0         180   540
# 5                           3      3     480      165   60         180   555
# 6                           4      5       0      420    0         420   600
# 7                           4      4     480      270    0         210   480
# 8                           4      3     600      135    0         180   525
# 9                           3      4     480      270    0         210   480
# 10                          4      3     480      180   60         120   480
# 11                          3      4     360      240  120         120   480
# 12                          4      3     380      180    0         120   480
# 13                          3      3     720      120    0         120   480
# 14                          3      3     480      120  120         240   480
# 15                          4      4     480      180   60         120   480
# 16                          4      3     480      120    0         180   480
# 17                          3      3     480      180   60         120   480
# 18                          4      4     480      120    0         180   480
# 19                          4      4     480      120   60         120   480
# 20                          3      2     600      240  180           0   420
# 21                          5      2     420      255  105          60   600
# 22                          4      3     510      195    0         210   525
# 23                          4      5     555      180    0         270   435
# 24                          3      3     480      360    0          60   540
# 25                          1      1       0      135  480         360   465
# 26                          4      2     660      300  120           0   360
# 27                          3      3     600      210    0         150   480
# 28                          4      4     285      315    0         180   690
# 29                          3      2     585      375    0         120   360
# 30                          3      2     480      105  120         120   600
# 31                          3      3     300      210  150         220   420
# 32                          2      4       0       90  750         180   480
# 33                          4      4     450      225  150         120   480
# 34                          4      4     290      300  120         120   480
# 35                          3      4     315      235  320         180   450
# 36                          4      4     480      145  180         120   420
# 37                          4      3     480      180   50         120   480
# 38                          3      2     465      115  120          90   480
# 39                          4      3     180      180  270         360   330
# 40                          2      2     600      140  400          35   300
# 41                          4      4     480      125  150         120   420
#
#     Tid_ensam  Tid_familj  Tid_vänner  Tid_övriga
# 0        1140         180           0         120
# 1        1080         360           0           0
# 2         810         330           0         300
# 3        1095         165          90          60
# 4         870         390           0         180
# 5        1320           0           0         120
# 6         720         720           0           0
# 7         660         300           0         480
# 8         840           0           0         600
# 9         960           0           0         480
# 10        540         180           0         420
# 11        600         360           0         300
# 12        440         180           0         420
# 13        120           0           0         720
# 14        120         680           0         600
# 15        540         180          60         420
# 16        480         180          60         480
# 17        540         180          60         420
# 18        600         360         300         300
# 19        540         240           0         480
# 20        705         225           0         510
# 21        995         400          45           0
# 22        700         225           0         440
# 23        510         400           0         645
# 24        420         300           0         510
# 25       1035         285         285         120
# 26       1140         510           0           0
# 27        938           0           0         502
# 28       1290           0         150           0
# 29        615         300           0         525
# 30        780           0          90         480
# 31       1200         120          30          60
# 32       1440           0           0           0
# 33        915          60         450           0
# 34       1200          60         120           0
# 35        615         510         150           0
# 36        800           0           0         595
# 37        640           0         120         670
# 38        745         105         315         180
# 39       1005         120         180           0
# 40        675           0           0         690
# 41        755           0         150         480

# %%
# Finding patterns in

# %%
df["Ålder"].median()
# Out:
# 35.0

# %%
df["Arbete"].median()/60
# Out:
# 8.0

# %%
df["Sömn"].median()/60
# Out:
# 8.0

# %%
df["Tid_ensam"].median()/60
# Out:
# 12.5

# %%
w = (df["Tid_familj"].median() + df["Tid_vänner"].median())/60
w
# Out:
# 3.0

# %%
df["Vardagstillfredsställelse"].median()
# Out:
# 4.0

# %%
df["Vardagstillfredsställelse"].value_counts()
# Out:
# 4    23
# 3    14
# 5     2
# 2     2
# 1     1
# Name: Vardagstillfredsställelse, dtype: int64

# %% [markdown]
# <h3>Hypotestest 1: Varians mellan män och kvinnor i vardagstillfredtställelse</h3>
#
# Konstruerar ett hypotestest som undersöker om variansen vad gäller vardagstillfredställelse är större för män än för kvinnor med $\alpha = 0.05$
#
# Vi börjar med att formulera våra hypoteser. Här vill vi göra ett ensidigt test mellan två varianser $\sigma^2_1$ och $\sigma^2_2$.
#
# Vi anger vår alternativhypotes:
#
# $H_A: \sigma^2_{man} > \sigma^2_{kvinna}$ <br>
#
# Det följer att nollhypotesen, alltså komplementet till alternativhypotesen då blir: <br>
#
# $H_0: \sigma^2_{man} \leq \sigma^2_{kvinna}$
#
# <br><br>
# Vi delar upp vårt ursprungsdataset i två delar, en som innehåller alla män och en som innehåller alla kvinnor.

# %%
male = df[df['Kön'] == 'Man']
female = df[df['Kön'] == 'Kvinna']

n_male = len(male)
n_female = len(female)

n_male + n_female
# Out:
# 42

# %%
print(male['Vardagstillfredsställelse'].sum()/n_male)
print(female['Vardagstillfredsställelse'].sum()/n_female)
# Out:
# 3.7222222222222223
# 3.4166666666666665

# %% [markdown]
# Nästa steg är att beräkna testfunktionen, i fallet med två varianser är det enkelt. Den ges av:
#
# $F=\frac{\sigma^2_1}{\sigma^2_2}$
#
#
# Vi kan alltså lätt räkna ut den med våra kända NumPy-metoder enligt följande:

# %%
statistic = np.var(male['Vardagstillfredsställelse'], ddof=1) / np.var(female['Vardagstillfredsställelse'], ddof=1)
print('F-statistic: ' + str(statistic))
# Out:
# F-statistic: 0.4256917720359171

# %% [markdown]
# Vi kan jämföra den med det kritiska värdet för vår F-fördelning (givet $\alpha = 0.05$) genom att hämta F-fördelningen i SciPy och kika i dess kumulativa fördelningsfunktion:

# %%
from scipy.stats import f

result = f.ppf(q=0.05, dfn=n_male-1, dfd=n_female-1)
print('F-critical :' +str(result))
# Out:
# F-critical :0.4548122708950203

# %% [markdown]
# Värdet på vår beräknade F-statistika (0.4257) är lägre än det kritiska värdet (0.4548), och vi kan därmed förkasta alternativhypotesen. Utifrån vårt test kan vi alltså konstatera att med ett konfidens på 95%, så skiljer sig **variansen** i vardagstillfredsställelse inte åt mellan män och kvinnor.
#
# ---

# %% [markdown]
# <h3>Exempel: Hypotestest för stickprovsmedelvärde med okänt sigma</h3>
# Konstruera ett hypotestest som undersöker om vardagstillfredtställelse för olika boendeformer skiljer sig.
# Vardagstillfredsställelse mäts på en skala mellan 1 och 5:
#
# 5 = Utmärkt
#
# 4 = Mycket god
#
# 3 = God
#
# 2 = Någorlunda
#
# 1 = Dålig
#
# Populationsmedelvärdet är:

# %%
df['Vardagstillfredsställelse'].sum()/len(df)
# Out:
# 3.5476190476190474

# %% [markdown]
# Vi utgår därför från att populationsmedelvärdet $\mu_0$ = 3.5476). Använd en signifikansnivå på $\alpha = 0.05$.
#
# Eftersom standardavvikelsen för populationen är okänd, kommer vi här använda oss av ett t-test.

# %%
from scipy.stats import t # Importera t-fördelningen ur SciPy

# %% [markdown]
# Vi börjar med att bestämma alternativhypotesen som:<br>
#     $H_A: \mu \neq 3.5476\,mm$<br>
# Och sedan nollhypotesen som dess komplement:<br>
#     $H_0: \mu = 3.5476\,mm$
#
# Sedan, beräknar vi teststatistikan för vår nollhypotes, d.v.s:
# <h3>
#
# $t = \frac{\overline{X} - \mu_0}{s \,/\sqrt{n}}$
#
# </h3>
#
# Det här kan vi göra på lite olika sätt. Först kan vi göra det med klassiska beräkningsmetoder vi kan i NumPy

# %%
Hyresrätt = df[df['Boende'] == 'Hyresrätt']
sample = Hyresrätt['Vardagstillfredsställelse']

xbar = sample.mean() # Beräkna stickprovsmedelvärde
mu = 3.5476 # Sätt mu till värde för nollhypotesen
std = sample.std(ddof=1) # beräkna standardavvikelsen för stickprovet
n = len(sample) # beräkna storleken på stickprovet

statistic = (xbar - mu) / (std / np.sqrt(n)) # Beräkna värdet på test-statistiskan
print('Test statistic: ' +str(statistic)) # Printa test-statistikan

p_value = 1 - t.cdf(x=statistic, df=n-1) # Beräkna p-värdet för stick provet som 1 - F(x=statistic)
print('p-value: ' + str(2*p_value)) # Printa p-värdet (2x beräknat värde p.g.a. två-sidigt test.
# Out:
# Test statistic: 0.19883879744260527
# p-value: 0.8438785807172322

# %% [markdown]
# <h5>Det finns också inbyggda funktioner för t.ex. t-test i SciPy, ni ska vi använda oss utav en av dem, vilket gör hela operationen mycket enklare.</h5>
# Vi använder oss av den inbyggda funktionen ttest_1samp(), vilken beräknar t-test statistiska samt dess p-värde givet ett set data och ett populationsmedelvärde. Vi använder oss här av alternative='two-sided', vilket ger oss det dubbel-sidiga testet för att vårt stickprovsmedelvärde är skilt från populationsmedelvärdet.<br>
# Dokumentationen till ttest_1samp() hittar vi <a href=https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_1samp.html>här</a>.

# %%
import scipy.stats as scs
result = scs.ttest_1samp(a=sample, popmean=mu, alternative='two-sided') # Genomför två-sidigt t-test m.h.a. ttest_1samp() i SciPy 

print(result) # Printa resultatet
# Out:
# TtestResult(statistic=0.19883879744260527, pvalue=0.8438785807172322, df=27)

# %% [markdown]
# Att använda den här funktionen blir väldigt praktiskt om vi t.ex. vill ändra på vår nollhypotes, låt säga att vi undrar om medelvärdet är större än 3.5476 istället (en en-sidig nollhypotes). Vi ändrar då bara alternative till 'greater'. Vi vet sen tidigare att det här egentligen mest bara lägger till en faktor 1/2 på p-värdet. På samma sätt kan vi också ändra till 'less', vilket då beräknar utifrån nollhypotesen att stickprovsmedelvärdet är mindre än populationsmedelvärdet.

# %%
result = scs.ttest_1samp(a=sample, popmean=mu, alternative='greater') # Genomför ensidigt t-test.

print(result) # Printa resultatet
# Out:
# TtestResult(statistic=0.19883879744260527, pvalue=0.4219392903586161, df=27)

# %% [markdown]
# Eftersom $p=0.042 < \alpha = 0.05$ kan vi med 95% konfidensgrad förkasta nollhypotesen att boenden i hyresrätter är samma som för alla boendeformer. Testet stödjer alltså tesen att hyresgäster har en vardagstillfredsställelse som skiljer sig från övriga boendeformer.

# %%
sample
# Out:
# 1     5
# 3     4
# 4     4
# 5     3
# 8     4
# 10    4
# 11    3
# 12    4
# 13    3
# 14    3
# 15    4
# 16    4
# 17    3
# 18    4
# 19    4
# 20    3
# 22    4
# 27    3
# 28    4
# 30    3
# 31    3
# 32    2
# 35    3
# 36    4
# 37    4
# 38    3
# 39    4
# 41    4
# Name: Vardagstillfredsställelse, dtype: int64

# %% [markdown]
# sample

# %% [markdown]
# <h3>Hypotestest 2: Varians mellan boende i hyresrätt och icke-hyresrätter i vardagstillfredtställelse</h3>
#
# Konstruera ett hypotestest som undersöker om vardagstillfredtställelse för boenden i hyresrätter skiljer sig från vardagstillfredtställelse för alla boendeformer (antag att populationsmedelvärdet $\mu_0$ = XXXSDDSD mm). Använd en signifikansnivå på $\alpha = 0.05$.
#
# Eftersom standardavvikelsen för populationen är okänd, kommer vi här använda oss av ett t-test.
